# %% [markdown]
# ## 1. Load dependencies and data
#
# We are using the following libraries:
# - `pandas` for data manipulation
# - `spacy` for natural language processing
# - `nltk` for natural language processing
# - `scipy` for sparse matrix handling
# - `sklearn` for dimensionality reduction
# - `sentence_transformers` for sentence embeddings

# %%
import pandas as pd
import spacy
import nltk

nlp = spacy.load("en_core_web_trf")

from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gyevn\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
explanations = pd.read_json('explanations.json', orient='index')  # Load explanations data
docs = list(nlp.pipe(explanations['Text']))  # Process all explanations
explanations.head()
# Out:
#                         PID  \
# 1  55b6a2e5fdf99b350d57360e
# 2  5f6f88cdb1ca47522ca4eef3
# 3  5eb4442bcaffba2864f4c554
# 4  60965962e523358592059dcb
# 5  5a440abd1ba496000102a238
#
#                                                 Text  QuestionType  SID
# 1  It was too far over to the left and was blocke...  Teleological    1
# 2                                 It needed to exit.  Teleological    1
# 3  The car needed to get over so he moved quickly...  Teleological    1
# 4  It wasn't in the correct lane, didn't get the ...  Teleological    1
# 5  It was in the wrong lane and had to make a qui...  Teleological    1

# %% [markdown]
# ## 2. Calculate word and sentence level statistics
#
# This includes the number of sentences, tokens, characters, words, and the minimum and maximum dependency depth of the dependency tree.

# %%
def to_nltk_tree(node) -> nltk.Tree:
    label = f"{node.orth_} ({node.dep_})"
    if node.n_lefts + node.n_rights > 0:
        return nltk.Tree(label, [to_nltk_tree(child) for child in node.children])
    else:
        return label
    
def dependency_lengths(node):
    if node.n_lefts + node.n_rights > 0:
        lens = []
        for child in node.children:
            if not child.is_punct:
                lens.append(abs(node.i - child.i))
                lens.extend(dependency_lengths(child))
        return lens
    else:
        return []

# %%
from collections import Counter

output = []
embedding = {}

for i, doc in enumerate(docs):
    # Dependency tree height
    dependency_trees = []
    for sent in doc.sents:
        tree = to_nltk_tree(sent.root)
        if not isinstance(tree, str):
            dependency_trees.append(tree)
    tree_heights = [tree.height() for tree in dependency_trees]
    
    # Dependency graph for dependency length calculation
    dep_lens = []
    for sent in doc.sents:
        dep_lens.extend(dependency_lengths(sent.root))
    
    lemmas = [token.lemma_ for token in doc if token.is_alpha and token.lemma_ not in stop_words]
    
    output.append({
        'NumSentences': len(list(doc.sents)),
        'NumTokens': len(doc),
        'NumChars': sum([len(sent.text) for sent in doc.sents]),
        "NumWords": sum([len(sent.text.split()) for sent in doc.sents]),
        "MinDepDepth": min(tree_heights),
        "MeanDepDepth": sum(tree_heights) / len(tree_heights),
        "MaxDepDepth": max(tree_heights),
        "MeanDepLength": sum(dep_lens) / len(dep_lens),
        "MaxDepLength": max(dep_lens), 
        "DependencyTrees": [" ".join(str(tree).split()) for tree in dependency_trees],
        "Type": explanations.loc[i+1, 'QuestionType'],
        "Text": doc.text,
        "WordCounts": dict(Counter(lemmas))
    })
# Out:
#    NumSentences  NumTokens  NumChars  NumWords  MinDepDepth  MeanDepDepth  \
# 1             2         37       162        35            5           5.0
# 2             1          5        18         4            3           3.0
# 3             2         30       133        28            4           5.5
# 4             1         22        97        18            7           7.0
# 5             1         17        69        16            5           5.0
#
#    MaxDepDepth  MeanDepLength  MaxDepLength  \
# 1            5       2.484848            10
# 2            3       1.333333             2
# 3            7       1.846154             6
# 4            7       2.263158             9
# 5            5       2.600000             6
#
#                                      DependencyTrees          Type  \
# 1  [(was (ROOT) It (nsubj) (to (prep) (over (advm...  Teleological
# 2  [(needed (ROOT) It (nsubj) (exit (xcomp) to (a...  Teleological
# 3  [(needed (ROOT) (car (nsubj) The (det)) (get (...  Teleological
# 4  [(was (ROOT) It (nsubj) n't (neg) (in (prep) (...  Teleological
# 5  [(was (ROOT) It (nsubj) (in (prep) (lane (pobj...  Teleological
#
#                                                 Text  \
# 1  It was too far over to the left and was blocke...
# 2                                 It needed to exit.
# 3  The car needed to get over so he moved quickly...
# 4  It wasn't in the correct lane, didn't get the ...
# 5  It was in the wrong lane and had to make a qui...
#
#                                           WordCounts
# 1  {'far': 1, 'left': 1, 'block': 1, 'two': 1, 'w...
# 2                             {'need': 1, 'exit': 1}
# 3  {'car': 2, 'need': 1, 'get': 1, 'move': 1, 'qu...
# 4  {'correct': 2, 'lane': 2, 'get': 2, 'prompt': ...
# 5  {'wrong': 1, 'lane': 2, 'make': 1, 'quick': 1,...

# %%
from src.get_anthroscore import get_text_score
import tqdm

import os, sys

class HiddenPrints:
    def __enter__(self):
        self._original_stdout = sys.stdout
        sys.stdout = open(os.devnull, 'w')

    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout.close()
        sys.stdout = self._original_stdout

# Get the AnthropoScore for each agent-related term in the explanation
entities = ["car", "self-driving car", "vehicle", "agent", "it"]
scores = []
with HiddenPrints():
    for text in tqdm.tqdm(output["Text"]):
        scores.append(get_text_score(text, entities))
output["AnthroScore"] = scores
# Out:
# 100%|██████████| 1308/1308 [06:06<00:00,  3.57it/s]

# %%
# Save output to JSON
output = pd.DataFrame(output, index=explanations.index)
output.to_json("linguistic_features.json", orient="index", indent=4)
output.head(10)
# Out:
#     NumSentences  NumTokens  NumChars  NumWords  MinDepDepth  MeanDepDepth  \
# 1              2         37       162        35            5           5.0
# 2              1          5        18         4            3           3.0
# 3              2         30       133        28            4           5.5
# 4              1         22        97        18            7           7.0
# 5              1         17        69        16            5           5.0
# 6              1          9        32         7            4           4.0
# 7              1         24       120        21            6           6.0
# 8              1         36       155        35           10          10.0
# 9              1         20        95        19            6           6.0
# 10             2         59       276        55            6           6.5
#
#     MaxDepDepth  MeanDepLength  MaxDepLength  \
# 1             5       2.484848            10
# 2             3       1.333333             2
# 3             7       1.846154             6
# 4             7       2.263158             9
# 5             5       2.600000             6
# 6             4       1.714286             3
# 7             6       2.666667             7
# 8            10       2.264706             9
# 9             6       2.333333             8
# 10            7       2.537037            16
#
#                                       DependencyTrees          Type  \
# 1   [(was (ROOT) It (nsubj) (to (prep) (over (advm...  Teleological
# 2   [(needed (ROOT) It (nsubj) (exit (xcomp) to (a...  Teleological
# 3   [(needed (ROOT) (car (nsubj) The (det)) (get (...  Teleological
# 4   [(was (ROOT) It (nsubj) n't (neg) (in (prep) (...  Teleological
# 5   [(was (ROOT) It (nsubj) (in (prep) (lane (pobj...  Teleological
# 6   [(want (ROOT) It (nsubj) did (aux) n't (neg) (...  Teleological
# 7   [(determined (ROOT) (car (nsubj) The (det) blu...  Teleological
# 8   [(needs (ROOT) It (nsubj) (get (xcomp) to (aux...  Teleological
# 9   [(took (ROOT) It (nsubj) (actions (dobj) these...  Teleological
# 10  [(took (ROOT) (car (nsubj) The (det) blue (amo...  Teleological
#
#                                                  Text  \
# 1   It was too far over to the left and was blocke...
# 2                                  It needed to exit.
# 3   The car needed to get over so he moved quickly...
# 4   It wasn't in the correct lane, didn't get the ...
# 5   It was in the wrong lane and had to make a qui...
# 6                    It didn't want to miss the exit.
# 7   The blue self-driving car determined that the ...
# 8   It needs to get to the offramp and its program...
# 9   It took these actions because the exit ramp wa...
# 10  The blue car took these actions because it wan...
#
#                                            WordCounts  Scores  AnthroScore
# 1   {'far': 1, 'left': 1, 'block': 1, 'two': 1, 'w...       1    -1.119358
# 2                              {'need': 1, 'exit': 1}       1     3.246491
# 3   {'car': 2, 'need': 1, 'get': 1, 'move': 1, 'qu...       1     5.815513
# 4   {'correct': 2, 'lane': 2, 'get': 2, 'prompt': ...       1     4.585336
# 5   {'wrong': 1, 'lane': 2, 'make': 1, 'quick': 1,...       1     6.097780
# 6                   {'want': 1, 'miss': 1, 'exit': 1}       1     6.189758
# 7   {'blue': 1, 'self': 1, 'drive': 1, 'car': 2, '...       1    -1.034934
# 8   {'need': 1, 'get': 2, 'offramp': 1, 'programmi...       1    -2.595084
# 9   {'take': 1, 'action': 1, 'exit': 1, 'ramp': 1,...       1     2.295882
# 10  {'blue': 1, 'car': 2, 'take': 1, 'action': 1, ...       1    -0.850519

# %% [markdown]
# ## 3. Visualize sentence-level sparse and dense embeddings
#
# For sparse embeddings, we use a TF-IDF vectorizer to create a sparse matrix of the text data. We then reduce the dimensionality of the matrix using TruncatedSVD and TSNE and plot the data colored by the question type.
#
# For dense embeddings, we use the `sentence_transformers` library to create sentence embeddings and reduce the dimensionality of the embeddings using PCA and TSNE. We then plot the data colored by the question type.
#
# You can however over the points to see the text of the explanation.

# %%
from scipy.sparse import issparse
from umap import UMAP
from sklearn.decomposition import TruncatedSVD, PCA
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sentence_transformers import SentenceTransformer

# %matplotlib qt
import matplotlib.pyplot as plt
import plotly.express as px

def create_embedding(X, dense=False):
    if not dense:
        if issparse(X):
            X_embedded = TruncatedSVD(n_components=25).fit_transform(X)
        else:
            X_embedded = PCA(n_components=25).fit_transform(X)
        X_embedded = UMAP(n_neighbors=15, n_components=2, min_dist=0.0, metric='cosine').fit_transform(X_embedded)
    else:
        sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
        X_embedded = sentence_model.encode(X)
    return X_embedded

# %%
# Create an embedding matrix from the text based on the tf-idf score of each term
vectorizer = TfidfVectorizer(stop_words="english")
X = vectorizer.fit_transform(output["Text"])

# Reduce the dimensionality of the embedding matrix and plot it colored by the question type
X_embedded = create_embedding(X.toarray())
fig = px.scatter(x=X_embedded[:, 0], y=X_embedded[:, 1], color=output['Type'], hover_data={"Text": output["Text"]})
fig.show()
# Out:
# <div>                            <div id="702726be-5586-4001-8c8f-80860f727093" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("702726be-5586-4001-8c8f-80860f727093")) {                    Plotly.newPlot(                        "702726be-5586-4001-8c8f-80860f727093",                        [{"customdata":[["It was too far over to the left and was blocked by two white cars. It needed to make its turn so it swerved between the white cars when the lead white car sped up."],["It needed to exit."],["The car needed to get over so he moved quickly across the lanes due to the presence of the car. You can only exit from the right lane."],["It wasn't in the correct lane, didn't get the correct prompts to get into the right lane earlier."],["It was in the wrong lane and had to make a quick lane change to exit."],["It didn't want to miss the exit."],["The blue self-driving car determined that the second white car was going slow enough that it could safely cross the gap."],["It needs to get to the offramp and its programming told it that the best way would be to pass the car and then turn in front of the car to get to the exit."],["It took these actions because the exit ramp was coming up soon and it was still two lanes over."],["The blue car took these actions because it wanted to exit off the freeway but it was in the overtaking lane at the time. So to save time and make sure it doesn't miss the exit, it quickly overtakes the white car next to it before cutting across 2 lanes to exit off the highway."],["It needed to change lanes and waited for the right moment to pass."],["It likely had only the command to exit and for some reason did not slow down to do so."],["The blue car was aiming to make the exit lane in time. It could have, however, moved into the right lane in the first place if it was programmed to exit rather than the last-minute maneuver it did."],["The car was programmed to exit the highway through the off-ramp."],["It was probably in a hurry and\u002for not paying attention."],["The self-driving car went between the cars in the right lane. I think it did this to keep up with the flow of traffic instead of slowing down."],["It took these actions because its goal was to leave the highway on the off-ramp to be able to do that it had to go to the right."],["The blue self-driving car took these actions to get off the highway and reach its destination based on prior predictions of previous rides."],["Having to maintain current speed was the logical choice."],["It was passing the car that was in the rear of the 2 cars in the slow lane. At this time, it estimated that if it was going to reach the exit in time, it would have to pass that car, but didn't have enough time to pass the other, so it merged in between them before merging into the exit lane."],["It saw a chance to exit the road even if it meant cutting a car off."],["To exit the highway quickly"],["The first white car (right to left) made space for the blue car to go between the two white cars."],["This was the quickest path."],["They assumed the other car got to the intersection after it and the blue car had the right away"],["Layout of the road, and signs, called for these actions"],["Its only obstacles were a stop sign and a turn it needed to make. Running the sign risks crashing or arrest, and to not make the turn would have it not reach its goal."],["It's the right way to follow its instructions"],["It knew the car was turning and felt it was safe to go"],["The car had to wait for clear traffic, and then apparently was able to tell the car on the main road had stopped to turn, which allowed for the blue car to turn right in this moment."],["The car analyzed that the oncoming car was turning thus found it safe to turn in front of the  ...

# %%
# Create a sparse embedding matrix from the dictionary counts
vectorizer = CountVectorizer(stop_words="english")
X = vectorizer.fit_transform(output["Text"])
word_counts = pd.DataFrame(X.sum(axis=0), columns=vectorizer.get_feature_names_out())

# Plot wordcloud for word counts
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(word_counts.iloc[0].to_dict())
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# Embed the lemma counts into 2D space and plot it by the question type
X_counts_embedded = create_embedding(X)
px.scatter(x=X_counts_embedded[:, 0], y=X_counts_embedded[:, 1], color=output['Type'], hover_data={"Text": output["Text"]}).show()
# Out:
# <div>                            <div id="75839ae0-72d5-43b1-abad-7c3498c5a92b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75839ae0-72d5-43b1-abad-7c3498c5a92b")) {                    Plotly.newPlot(                        "75839ae0-72d5-43b1-abad-7c3498c5a92b",                        [{"customdata":[["It was too far over to the left and was blocked by two white cars. It needed to make its turn so it swerved between the white cars when the lead white car sped up."],["It needed to exit."],["The car needed to get over so he moved quickly across the lanes due to the presence of the car. You can only exit from the right lane."],["It wasn't in the correct lane, didn't get the correct prompts to get into the right lane earlier."],["It was in the wrong lane and had to make a quick lane change to exit."],["It didn't want to miss the exit."],["The blue self-driving car determined that the second white car was going slow enough that it could safely cross the gap."],["It needs to get to the offramp and its programming told it that the best way would be to pass the car and then turn in front of the car to get to the exit."],["It took these actions because the exit ramp was coming up soon and it was still two lanes over."],["The blue car took these actions because it wanted to exit off the freeway but it was in the overtaking lane at the time. So to save time and make sure it doesn't miss the exit, it quickly overtakes the white car next to it before cutting across 2 lanes to exit off the highway."],["It needed to change lanes and waited for the right moment to pass."],["It likely had only the command to exit and for some reason did not slow down to do so."],["The blue car was aiming to make the exit lane in time. It could have, however, moved into the right lane in the first place if it was programmed to exit rather than the last-minute maneuver it did."],["The car was programmed to exit the highway through the off-ramp."],["It was probably in a hurry and\u002for not paying attention."],["The self-driving car went between the cars in the right lane. I think it did this to keep up with the flow of traffic instead of slowing down."],["It took these actions because its goal was to leave the highway on the off-ramp to be able to do that it had to go to the right."],["The blue self-driving car took these actions to get off the highway and reach its destination based on prior predictions of previous rides."],["Having to maintain current speed was the logical choice."],["It was passing the car that was in the rear of the 2 cars in the slow lane. At this time, it estimated that if it was going to reach the exit in time, it would have to pass that car, but didn't have enough time to pass the other, so it merged in between them before merging into the exit lane."],["It saw a chance to exit the road even if it meant cutting a car off."],["To exit the highway quickly"],["The first white car (right to left) made space for the blue car to go between the two white cars."],["This was the quickest path."],["They assumed the other car got to the intersection after it and the blue car had the right away"],["Layout of the road, and signs, called for these actions"],["Its only obstacles were a stop sign and a turn it needed to make. Running the sign risks crashing or arrest, and to not make the turn would have it not reach its goal."],["It's the right way to follow its instructions"],["It knew the car was turning and felt it was safe to go"],["The car had to wait for clear traffic, and then apparently was able to tell the car on the main road had stopped to turn, which allowed for the blue car to turn right in this moment."],["The car analyzed that the oncoming car was turning thus found it safe to turn in front of the  ...

# %%
# Create a sentence-bert embedding matrix from the text
embedded = create_embedding(output["Text"], dense=True)
embedded = create_embedding(embedded, dense=False)
fig = px.scatter(x=embedded[:, 0], y=embedded[:, 1], color=output['Type'], hover_data={"Text": output["Text"]})
fig.show()
# Out:
# <div>                            <div id="8675a94f-6c40-44f6-b3d3-e1df801bb8c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8675a94f-6c40-44f6-b3d3-e1df801bb8c2")) {                    Plotly.newPlot(                        "8675a94f-6c40-44f6-b3d3-e1df801bb8c2",                        [{"customdata":[["It was too far over to the left and was blocked by two white cars. It needed to make its turn so it swerved between the white cars when the lead white car sped up."],["It needed to exit."],["The car needed to get over so he moved quickly across the lanes due to the presence of the car. You can only exit from the right lane."],["It wasn't in the correct lane, didn't get the correct prompts to get into the right lane earlier."],["It was in the wrong lane and had to make a quick lane change to exit."],["It didn't want to miss the exit."],["The blue self-driving car determined that the second white car was going slow enough that it could safely cross the gap."],["It needs to get to the offramp and its programming told it that the best way would be to pass the car and then turn in front of the car to get to the exit."],["It took these actions because the exit ramp was coming up soon and it was still two lanes over."],["The blue car took these actions because it wanted to exit off the freeway but it was in the overtaking lane at the time. So to save time and make sure it doesn't miss the exit, it quickly overtakes the white car next to it before cutting across 2 lanes to exit off the highway."],["It needed to change lanes and waited for the right moment to pass."],["It likely had only the command to exit and for some reason did not slow down to do so."],["The blue car was aiming to make the exit lane in time. It could have, however, moved into the right lane in the first place if it was programmed to exit rather than the last-minute maneuver it did."],["The car was programmed to exit the highway through the off-ramp."],["It was probably in a hurry and\u002for not paying attention."],["The self-driving car went between the cars in the right lane. I think it did this to keep up with the flow of traffic instead of slowing down."],["It took these actions because its goal was to leave the highway on the off-ramp to be able to do that it had to go to the right."],["The blue self-driving car took these actions to get off the highway and reach its destination based on prior predictions of previous rides."],["Having to maintain current speed was the logical choice."],["It was passing the car that was in the rear of the 2 cars in the slow lane. At this time, it estimated that if it was going to reach the exit in time, it would have to pass that car, but didn't have enough time to pass the other, so it merged in between them before merging into the exit lane."],["It saw a chance to exit the road even if it meant cutting a car off."],["To exit the highway quickly"],["The first white car (right to left) made space for the blue car to go between the two white cars."],["This was the quickest path."],["They assumed the other car got to the intersection after it and the blue car had the right away"],["Layout of the road, and signs, called for these actions"],["Its only obstacles were a stop sign and a turn it needed to make. Running the sign risks crashing or arrest, and to not make the turn would have it not reach its goal."],["It's the right way to follow its instructions"],["It knew the car was turning and felt it was safe to go"],["The car had to wait for clear traffic, and then apparently was able to tell the car on the main road had stopped to turn, which allowed for the blue car to turn right in this moment."],["The car analyzed that the oncoming car was turning thus found it safe to turn in front of the  ...

# %% [markdown]
# ## 4. Perform sentence embedding for parse trees to compare similarities
#
# This is done by taking the flattened tree structure of each dependency parse tree and running it through sentence-bert then applying the same dimensionality reduction and plotting as before.

# %%
embedded = create_embedding(output["DependencyTrees"], dense=True)
embedded = create_embedding(embedded, dense=False)
fig = px.scatter(x=embedded[:, 0], y=embedded[:, 1], color=output['Type'], hover_data={"Text": output["Text"]})
fig.show()
# Out:
# <div>                            <div id="ec57ecee-2da4-46ad-96ac-126161bdcbb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec57ecee-2da4-46ad-96ac-126161bdcbb1")) {                    Plotly.newPlot(                        "ec57ecee-2da4-46ad-96ac-126161bdcbb1",                        [{"customdata":[["It was too far over to the left and was blocked by two white cars. It needed to make its turn so it swerved between the white cars when the lead white car sped up."],["It needed to exit."],["The car needed to get over so he moved quickly across the lanes due to the presence of the car. You can only exit from the right lane."],["It wasn't in the correct lane, didn't get the correct prompts to get into the right lane earlier."],["It was in the wrong lane and had to make a quick lane change to exit."],["It didn't want to miss the exit."],["The blue self-driving car determined that the second white car was going slow enough that it could safely cross the gap."],["It needs to get to the offramp and its programming told it that the best way would be to pass the car and then turn in front of the car to get to the exit."],["It took these actions because the exit ramp was coming up soon and it was still two lanes over."],["The blue car took these actions because it wanted to exit off the freeway but it was in the overtaking lane at the time. So to save time and make sure it doesn't miss the exit, it quickly overtakes the white car next to it before cutting across 2 lanes to exit off the highway."],["It needed to change lanes and waited for the right moment to pass."],["It likely had only the command to exit and for some reason did not slow down to do so."],["The blue car was aiming to make the exit lane in time. It could have, however, moved into the right lane in the first place if it was programmed to exit rather than the last-minute maneuver it did."],["The car was programmed to exit the highway through the off-ramp."],["It was probably in a hurry and\u002for not paying attention."],["The self-driving car went between the cars in the right lane. I think it did this to keep up with the flow of traffic instead of slowing down."],["It took these actions because its goal was to leave the highway on the off-ramp to be able to do that it had to go to the right."],["The blue self-driving car took these actions to get off the highway and reach its destination based on prior predictions of previous rides."],["Having to maintain current speed was the logical choice."],["It was passing the car that was in the rear of the 2 cars in the slow lane. At this time, it estimated that if it was going to reach the exit in time, it would have to pass that car, but didn't have enough time to pass the other, so it merged in between them before merging into the exit lane."],["It saw a chance to exit the road even if it meant cutting a car off."],["To exit the highway quickly"],["The first white car (right to left) made space for the blue car to go between the two white cars."],["This was the quickest path."],["They assumed the other car got to the intersection after it and the blue car had the right away"],["Layout of the road, and signs, called for these actions"],["Its only obstacles were a stop sign and a turn it needed to make. Running the sign risks crashing or arrest, and to not make the turn would have it not reach its goal."],["It's the right way to follow its instructions"],["It knew the car was turning and felt it was safe to go"],["The car had to wait for clear traffic, and then apparently was able to tell the car on the main road had stopped to turn, which allowed for the blue car to turn right in this moment."],["The car analyzed that the oncoming car was turning thus found it safe to turn in front of the  ...

# %% [markdown]
# ## 5. Topic analysis with BERTopic

# %%
from bertopic import BERTopic
from umap import UMAP
from bertopic.vectorizers import ClassTfidfTransformer

ctfidf_model = ClassTfidfTransformer()
sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = sentence_model.encode(output["Text"], show_progress_bar=False)

# Train BERTopic
topic_model = BERTopic(ctfidf_model=ctfidf_model).fit(output["Text"], embeddings)

# Reduce dimensionality of embeddings, this step is optional but much faster to perform iteratively:
reduced_embeddings = UMAP(n_neighbors=10, n_components=2, min_dist=0.0, metric='cosine').fit_transform(embeddings)
topic_model.visualize_documents(output["Text"], reduced_embeddings=reduced_embeddings)
# Out:
# <div>                            <div id="4ed1e5d9-924c-4efa-ac3a-00db8dc34528" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ed1e5d9-924c-4efa-ac3a-00db8dc34528")) {                    Plotly.newPlot(                        "4ed1e5d9-924c-4efa-ac3a-00db8dc34528",                        [{"hoverinfo":"text","hovertext":["The blue car entered the round about with out yielding as was required another car was just existing the round about","The blue car had the right of way.","The car could have been instructed not to slow down when passing parked cars. This would have increased the chance of an accident though, as one did pull out.","The blue car recognized an object in the road (the ball) and came to a stop before the person followed. Then after the person had crossed, the car resumed driving.","It shouldn't have gone too close to parked cars before it made a slight turn. It's not safe.","The blue car was aiming to make the exit lane in time. It could have, however, moved into the right lane in the first place if it was programmed to exit rather than the last-minute maneuver it did.","Went straight but slowed and stopped when there was a car pulling out","If the line of parked cars wasn't there, the blue car could have seen the kid earlier and slowed. It could also have ignored the kid and not slowed down at all.","The blue car stopped when it saw a ball roll into the street followed by a person","It slowed down, because had it not, it probably would have hit the person who was crossing the road.","Pedestrians stepped out into the crosswalk in front of the self-driving car.","It waited to see the actions of the other cars before determining its course.","It was influenced by its programming and the person on the street.","If the van was not in the way the blue car could quickly go around the parked cars and turn at the junction.","If the goal is to fall in line behind the waiting cars, there is no other scenario to describe which the car can take.","The action of the blue car was perfect since it waited patiently for the on coming car","It briefly slows down before entering and then proceeds to its exit.","It was impatient! It could have stopped and waited for the car in front to park.","The blue self-driving car could have determined that the white car was stopped so that it needed to pass to continue on its goal.","The blue car could have moved into the right lane prior to exiting, which would mean that it did not have to wait for an opening to quickly exit on the ramp.","The blue car pulled around the white car and then continued straight.","If it did not slow down it would have hit the kid in the parking lot.","It didn't want to hit a car, but also wanted to get to the off-ramp as fast as possible.","It could not go around the van because there was a car coming in the opposite direction.","It wanted to be clear of any obstacles in front of it.","It took these actions because its goal was to leave the highway on the off-ramp to be able to do that it had to go to the right.","The blue car could have waited for the other cars to make their own decisions before it turned right.","It was being overly cautious.","Because the safest thing to do is to stop for a pedestrian rather than doing something like quickly going around them.","The blue car exited the highway.","It noticed that the car was in a lane that must turn right.","It was only influenced by it's path, and whether pedestrians were crossing.","It has to wait for the actions of the other car on the road","Driving behind another car that intended to park - the car swung out & went around the car as it pulled into the spot","If there was no one in the crosswalk, the blue car wouldn't have had to stop","The blue changed lanes to get i ...

# %%
# Visual hierarchy of topics
hierarchical_topics = topic_model.hierarchical_topics(output["Text"])
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics).show()
# Out:
# 100%|██████████| 28/28 [00:00<00:00, 285.55it/s]
# <div>                            <div id="7965b297-0111-492e-92a6-e1e2ac59c222" class="plotly-graph-div" style="height:635px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7965b297-0111-492e-92a6-e1e2ac59c222")) {                    Plotly.newPlot(                        "7965b297-0111-492e-92a6-e1e2ac59c222",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["goal_simplest_way_reach_its","","","goal_its_obstacle_path_blue"],"x":[0.0,0.5827234634787646,0.5827234634787646,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["this_road_stay_quickest_logical","","","exit_command_needed_get_to"],"x":[0.0,0.6363711202524688,0.6363711202524688,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["exit_this_to_needed_it","","","programmed_computer_program_was_to"],"x":[0.6363711202524688,0.7818151278245917,0.7818151278245917,0.0],"xaxis":"x","y":[-30.0,-30.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["goal_its_reach_way_most","","","programmed_was_to_exit_it"],"x":[0.5827234634787646,0.8794573676817199,0.8794573676817199,0.7818151278245917],"xaxis":"x","y":[-10.0,-10.0,-37.5,-37.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["safest_actions_these_his_remain","","","actions_these_safety_took_bestsafest"],"x":[0.0,0.5385350312072177,0.5385350312072177,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","text":["programmed_goal_was_its_to","","","actions_safest_these_took_safety"],"x":[0.8794573676817199,1.0151877875680644,1.0151877875680644,0.5385350312072177],"xaxis":"x","y":[-23.75,-23.75,-60.0,-60.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["pedestrians_cross_crosswalk_street_right","","","pedestrians_crosswalk_crossing_crosswalks_pedestrian"],"x":[0.0,0.38435098491400266,0.38435098491400266,0.0],"xaxis":"x","y":[-85.0,-85.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["ball_pedestrian_person_kid_them","","","pedestrians_cross_crosswalk_street_people"],"x":[0.0,0.8744872419261048,0.8744872419261048,0.38435098491400266],"xaxis":"x","y":[-75.0,-75.0,-90.0,-90.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","text":["sign_stop_stopped_blue_car","","","stop_turned_sign_right_left"],"x":[0.0,0.272166310424072,0.272166310424072,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","text":["sign_signs_stop_traffic_make","","","stop_sign_stopped_right_turned"],"x":[0.0,0.605353005992583,0.605353005992583,0.272166310424072],"xaxis":"x","y":[-105.0,-105.0,-120.0,-120.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","text":["influenced_by_was_it_turning","","","influenced_by_presence_decisions_blue"],"x":[0.0,0.3954815655106372,0.3954815655106372,0.0],"xaxis":"x","y":[-135.0,-135.0,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","text":["sign_stop_stopped_the_intersection","","","influenced_by_was_it_turning"],"x":[0.605353005992583,0.9221827730154013,0.9221827730154013,0.3954815655106372],"xaxis":"x","y":[-112.5,-112.5,-140.0,-140.0],"yaxis":" ...
